# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:\\Users\\GPT BANTWAL\\Documents\\mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
range=(10,40)
bins=10
plt.hist(df['mpg'],bins,range,color="green",rwidth=0.8)
plt.xlabel('mpg')
plt.ylabel('frequency')
plt.title('histogram')
plt.show()

# %%
plt.scatter(df['wt'],df['mpg'],color="black",marker="*")
plt.xlabel('weight of the car')
plt.ylabel('mpg')
plt.title('scatterplot')
plt.show()

# %%
temp=df['am']=pd.values_[counts]
print(temp)
temp.plt.bar()
plt.xlabel('frequency')
plt.ylabel('mpg')
plt.title('barplot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 temp=df['am']=pd.values_[counts]
#       2 print(temp)
#       3 temp.plt.bar()
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'values_'

# %%
plt.box(df['mpg'])
plt.box()
plt.ylabel('mpg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 2
#       1 plt.box(df['mpg'])
# ----> 2 plt.box()
#       3 plt.ylabel('mpg')
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1755, in box(on)
#    1753 ax = gca()
#    1754 if on is None:
# -> 1755     on = not ax.get_frame_on()
#    1756 ax.set_frame_on(on)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ...

# %%
import pandas as pd
arr={'day':[1,2,3,4,5,5,7,8,9,10],
     'steps':[4335,9552,7332,4504,5335,7552,8332,6504,8965,7689]}
df=pd.DataFrame(arr)
df
# Out:
#    day  steps
# 0    1   4335
# 1    2   9552
# 2    3   7332
# 3    4   4504
# 4    5   5335
# 5    5   7552
# 6    7   8332
# 7    8   6504
# 8    9   8965
# 9   10   7689

# %%
steps_tracker['steps']=df.arr['steps']+1000
print(steps_tracker['steps'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 steps_tracker['steps']=df.arr['steps']+1000
#       2 print(steps_tracker['steps'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'arr'

# %%
arr['steps']=df(arr['steps']+1000)
print(arr['steps'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 arr['steps']=df(arr['steps']+1000)
#       2 print(arr['steps'])
#
# TypeError: can only concatenate list (not "int") to list

# %%
match=df.loc(arr['steps'])>7000
print(match)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 match=df.loc(arr['steps'])>7000
#       2 print(match)
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:668, in _LocationIndexer.__call__(self, axis)
#     665 new_self = type(self)(self.name, self.obj)
#     667 if axis is not None:
# --> 668     axis = self.obj._get_axis_number(axis)
#     669 new_self.axis = axis
#     670 return new_self
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     550 @final
#     551 @classmethod
#     552 def _get_axis_number(cls, axis: Axis) -> int:
#     553     try:
# --> 554         return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555     except KeyError:
#     556         raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'list'
